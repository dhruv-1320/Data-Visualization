# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prom = pd.read_csv("HR.csv")

# %%
prom.shape
# Out:
# (54808, 15)

# %%
prom.size
# Out:
# 822120

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.drop('employee_id', axis=1 ,inplace = True)
#
# NameError: name 'df' is not defined

# %%
prom.dtypes
# Out:
# Employee_id               int64
# Gender                   object
# Age                       int64
# Department               object
# Is_promoted               int64
# Region                   object
# Education                object
# Recruitment_channel      object
# No_of_trainings           int64
# Previous_year_rating    float64
# Length_of_service         int64
# KPIs_met >80%             int64
# Awards_won                int64
# Avg_training_score        int64
# Unnamed: 14             float64
# dtype: object

# %%
prom.drop('Employee_id', axis=1 ,inplace = True)

# %%
prom.isnull().values.any()
# Out:
# True

# %%
prom.iloc[:,:-1].describe()
# Out:
#         Employee_id           Age   Is_promoted  No_of_trainings  \
# count  54808.000000  54808.000000  54808.000000     54808.000000
# mean   39195.830627     34.803915      0.085170         1.253011
# std    22586.581449      7.660169      0.279137         0.609264
# min        1.000000     20.000000      0.000000         1.000000
# 25%    19669.750000     29.000000      0.000000         1.000000
# 50%    39225.500000     33.000000      0.000000         1.000000
# 75%    58730.500000     39.000000      0.000000         1.000000
# max    78298.000000     60.000000      1.000000        10.000000
#
#        Previous_year_rating  Length_of_service  KPIs_met >80%    Awards_won  \
# count          50684.000000       54808.000000   54808.000000  54808.000000
# mean               3.329256           5.865512       0.351974      0.023172
# std                1.259993           4.265094       0.477590      0.150450
# ...

# %%
sns.pairplot(data=prom, vars=['Is_promoted', 'KPIs_met >80%', 'No_of_trainings'], hue='Is_promoted')
plt.show()

# %%
corr_matrix = prom.iloc[:,0:14].corr()

corr_matrix
# Out:
# C:\Users\mukes\AppData\Local\Temp\ipykernel_135348\2509736628.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = prom.iloc[:,0:14].corr()
#                       Employee_id       Age  Is_promoted  No_of_trainings  \
# Employee_id              1.000000  0.000437    -0.007234        -0.005121
# Age                      0.000437  1.000000    -0.058500        -0.081278
# Is_promoted             -0.007234 -0.058500     1.000000         0.583413
# No_of_trainings         -0.005121 -0.081278     0.583413         1.000000
# Previous_year_rating     0.004533  0.006008    -0.037524        -0.063126
# Length_of_service        0.001274  0.657111    -0.038900        -0.057275
# KPIs_met >80%           -0.002501 -0.025592    -0.027922        -0.045576
# ...

# %%
sns.pairplot(data=prom, vars=['No_of_trainings', 'Avg_training_score', 'KPIs_met >80%'], hue='Is_promoted')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %%
sns.heatmap(corr_matrix,annot=True,cmap='RdBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()
